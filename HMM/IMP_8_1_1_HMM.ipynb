# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 1.7 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/IMP.csv'
# company_csv = '/content/drive/MyDrive/Colab Notebooks/VMD.csv'

df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02  10760  10790  10760  10790    2410    IMP
# 1              1  2014-01-03  10760  10840  10670  10840   13010    IMP
# 2              2  2014-01-06  10870  11560  10870  11540   55630    IMP
# 3              3  2014-01-07  11400  11540  11330  11540   20980    IMP
# 4              4  2014-01-08  11370  11830  11330  11800   43410    IMP
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2462        2462  2023-12-04  54700  55500  54400  55300   24800    IMP
# 2463        2463  2023-12-05  55200  55200  54600  55000   10200    IMP
# 2464        2464  2023-12-06  55000  55200  54900  55200   26600    IMP
# 2465        2465  2023-12-07  54900  55900  54900  55200   29200    IMP
# 2466        2466  2023-12-08  55200  55200  54500  55200    6300    IMP
#
# [2467 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %%
# Split the data
train_size = int(0.8 * len(data))
test_size = int(0.1 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 1395.3158701321402 is not greater than 1395.3425357796584. Delta is -0.026665647518257174
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1867997089666 is not greater than 1399.1868749564776. Delta is -7.52475109493389e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1868027420744 is not greater than 1399.1868610871447. Delta is -5.834507032886904e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 1395.3158701321408 is not greater than 1395.342535779665. Delta is -0.02666564752416889
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1867997089687 is not greater than 1399.1868749564755. Delta is -7.524750685661274e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1868027420753 is not greater than 1399.1868610871472. Delta is -5.834507192048477e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0367132726974 is not greater than 2867.039318898219. Delta is -0.0026056255214825796
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.036605597327 is not greater than 2867.039653454439. Delta is -0.0030478571120511333
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.2052840824545 is not greater than 3042.206024015047. Delta is -0.0007399325927508471
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0365629179487 is not greater than 2867.0401982987164. Delta is -0.0036353807677187433
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0363952966513 is not greater than 2867.0372552247163. Delta is -0.0008599280649832508
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.037065517952 is not greater than 2867.046716360682. Delta is -0.009650842729570286
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1898542243457 is not greater than 1399.1907116896914. Delta is -0.0008574653456889791
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0365445560674 is not greater than 2867.039913610286. Delta is -0.003369054218637757
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0397700427498 is not greater than 2867.040345803613. Delta is -0.0005757608632848132
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0367132727106 is not greater than 2867.039318898231. Delta is -0.002605625520573085
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.036605597334 is not greater than 2867.0396534544516. Delta is -0.0030478571175081015
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.205284082478 is not greater than 3042.206024015053. Delta is -0.0007399325750157004
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.036562917953 is not greater than 2867.040198298706. Delta is -0.003635380753166828
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0363952966813 is not greater than 2867.0372552248145. Delta is -0.0008599281331953534
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.037065517966 is not greater than 2867.0467163607045. Delta is -0.009650842738665233
# WARNING:hmmlearn.base:Model is not converging.  Current: 1399.1898542243293 is not greater than 1399.190711689759. Delta is -0.0008574654295898654
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.036544556069 is not greater than 2867.0399136102897. Delta is -0.0033690542204567464
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0397700427548 is not greater than 2867.0403458036185. Delta is -0.0005757608637395606
# WARNING:hmmlearn.base:Model is not converging.  Current: 3414.619790804184 is not greater than 3414.622673879462. Delta is -0.0028830752780777402
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0947023514314 is not greater than 2867.1010126289766. Delta is -0.006310277545253484
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.603911700034 is not greater than 3443.60738577447. Delta is -0.0034740744358714437
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.1952757411527 is not greater than 3042.1975067808976. Delta is -0.002231039744856389
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.118316095838 is not greater than 2867.1291376423064. Delta is -0.010821546468378074
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.2047412112775 is not greater than 3042.2048843102734. Delta is -0.00014309899597719777
# WARNING:hmmlearn.base:Model is not converging.  Current: 3483.6469916950773 is not greater than 3483.647055032852. Delta is -6.333777491818182e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 3414.6197908041786 is not greater than 3414.6226738794558. Delta is -0.0028830752771682455
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.0947023513713 is not greater than 2867.10101262908. Delta is -0.006310277708507783
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.603911699822 is not greater than 3443.6073857746037. Delta is -0.0034740747814794304
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.1952757411755 is not greater than 3042.1975067809226. Delta is -0.0022310397471301258
# WARNING:hmmlearn.base:Model is not converging.  Current: 2867.1183160958412 is not greater than 2867.1291376423073. Delta is -0.010821546466104337
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.2047412112793 is not greater than 3042.2048843102752. Delta is -0.00014309899597719777
# WARNING:hmmlearn.base:Model is not converging.  Current: 3483.6469916951914 is not greater than 3483.647055032743. Delta is -6.333755163723254e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.1577962501074 is not greater than 3042.1671043286124. Delta is -0.009308078505000594
# WARNING:hmmlearn.base:Model is not converging.  Current: 3407.8812492286206 is not greater than 3407.8883286161363. Delta is -0.007079387515659619
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.5832367678577 is not greater than 3443.584093819063. Delta is -0.0008570512054575374
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.1577962501315 is not greater than 3042.1671043285246. Delta is -0.009308078393132746
# WARNING:hmmlearn.base:Model is not converging.  Current: 3407.881249228633 is not greater than 3407.888328616113. Delta is -0.007079387480189325
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.583236767883 is not greater than 3443.584093819074. Delta is -0.0008570511909056222
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.5787647903226 is not greater than 3443.585976817267. Delta is -0.007212026944216632
# WARNING:hmmlearn.base:Model is not converging.  Current: 3443.578764790318 is not greater than 3443.585976817268. Delta is -0.007212026950128347
# WARNING:hmmlearn.base:Model is not converging.  Current: 3349.8473309171886 is not greater than 3349.8549992199896. Delta is -0.0076683028009938425
# WARNING:hmmlearn.base:Model is not converging.  Current: 3349.8473309171904 is not greater than 3349.8549992199855. Delta is -0.007668302795082127
# WARNING:hmmlearn.base:Model is not converging.  Current: 3401.2155990934784 is not greater than 3401.2710262181613. Delta is -0.055427124682864815
# WARNING:hmmlearn.base:Model is not converging.  Current: 3401.21559909347 is not greater than 3401.271026218193. Delta is -0.05542712472333733

# %%
best_params ={'n_components': 2, 'covariance_type': 'tied', 'random_state': 32}
# {'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# GaussianHMM(covariance_type='tied', n_components=2, n_iter=100, random_state=32)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  10559.083147046445
# MAPE:  16.793125412196595
# R-squared:  -2.4782066389395285
# RMSE:  14171.32731679931
#
# ** Validate **
# MAE:  9879.975458755509
# MAPE:  18.58555823395875
# R-squared:  -2.271073003815146
# RMSE:  12215.574260326037

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
