# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 3.0 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
# company_csv = '/content/drive/MyDrive/Colab Notebooks/OPC.csv'
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/OPC.csv'
df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02   9910   9910   9850   9850   12650    OPC
# 1              1  2014-01-03   9150   9910   9150   9910    2160    OPC
# 2              2  2014-01-06   9450   9850   9450   9850    1090    OPC
# 3              3  2014-01-07   9850   9850   9850   9850     200    OPC
# 4              4  2014-01-08   9450   9910   9450   9850    1290    OPC
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2463        2463  2023-12-04  22500  22900  22500  22900   15300    OPC
# 2464        2464  2023-12-05  22900  22900  22900  22900   18500    OPC
# 2465        2465  2023-12-06  22900  22950  22900  22900   26000    OPC
# 2466        2466  2023-12-07  22900  22900  22600  22900   19100    OPC
# 2467        2467  2023-12-08  22900  22900  22900  22900   15000    OPC
#
# [2468 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %%
# Split the data
train_size = int(0.6 * len(data))
test_size = int(0.3 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3164393071966 is not greater than 1784.317080314505. Delta is -0.0006410073083316092
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3165955742709 is not greater than 1784.317174323137. Delta is -0.000578748866018941
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3164393071975 is not greater than 1784.3170803145117. Delta is -0.0006410073142433248
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3165955742734 is not greater than 1784.3171743231364. Delta is -0.0005787488630630833
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3026771176978 is not greater than 1784.3068602707913. Delta is -0.004183153093435976
# WARNING:hmmlearn.base:Model is not converging.  Current: 2250.062603725675 is not greater than 2250.408900123532. Delta is -0.3462963978568041
# WARNING:hmmlearn.base:Model is not converging.  Current: 1892.5017719113707 is not greater than 1892.5019860203424. Delta is -0.00021410897170426324
# WARNING:hmmlearn.base:Model is not converging.  Current: 2225.1186865604177 is not greater than 2225.1202891943954. Delta is -0.0016026339776544773
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3537217088904 is not greater than 1784.3547344414637. Delta is -0.0010127325733719772
# WARNING:hmmlearn.base:Model is not converging.  Current: 2225.118278874366 is not greater than 2225.120725230038. Delta is -0.002446355671963829
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3026771176894 is not greater than 1784.3068602707954. Delta is -0.004183153105941528
# WARNING:hmmlearn.base:Model is not converging.  Current: 2250.0626037256875 is not greater than 2250.4089001235475. Delta is -0.34629639785998734
# WARNING:hmmlearn.base:Model is not converging.  Current: 1892.5017719113823 is not greater than 1892.5019860203486. Delta is -0.00021410896624729503
# WARNING:hmmlearn.base:Model is not converging.  Current: 2225.118686560407 is not greater than 2225.1202891944185. Delta is -0.0016026340117605287
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3537217088783 is not greater than 1784.3547344414465. Delta is -0.0010127325681423827
# WARNING:hmmlearn.base:Model is not converging.  Current: 2225.1182788744118 is not greater than 2225.1207252300696. Delta is -0.002446355657866661
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3466389457412 is not greater than 1784.3478935391213. Delta is -0.0012545933800538478
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.290543119434 is not greater than 2410.290814035321. Delta is -0.0002709158870857209
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.057501056032 is not greater than 2410.1015817102893. Delta is -0.0440806542574137
# WARNING:hmmlearn.base:Model is not converging.  Current: 1784.3466389456757 is not greater than 1784.3478935391. Delta is -0.0012545934241643408
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.290543119479 is not greater than 2410.290814035347. Delta is -0.00027091586798633216
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.057501056029 is not greater than 2410.101581710297. Delta is -0.04408065426787289
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.6648307951764 is not greater than 2409.6696291474786. Delta is -0.004798352302259445
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.6648307951828 is not greater than 2409.6696291474755. Delta is -0.004798352292709751
# WARNING:hmmlearn.base:Model is not converging.  Current: 2647.834521233913 is not greater than 2647.8403930887994. Delta is -0.005871854886208894
# WARNING:hmmlearn.base:Model is not converging.  Current: 2408.9376282707076 is not greater than 2408.9577506402097. Delta is -0.020122369502132642
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.053396797957 is not greater than 2410.0540242291722. Delta is -0.0006274312154346262
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.777205258882 is not greater than 2409.778146570798. Delta is -0.0009413119159944472
# WARNING:hmmlearn.base:Model is not converging.  Current: 2647.8345212339173 is not greater than 2647.8403930888003. Delta is -0.005871854883025662
# WARNING:hmmlearn.base:Model is not converging.  Current: 2408.9376282707 is not greater than 2408.9577506401783. Delta is -0.02012236947848578
# WARNING:hmmlearn.base:Model is not converging.  Current: 2410.0533967980027 is not greater than 2410.054024229177. Delta is -0.0006274311740526173
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.777205258867 is not greater than 2409.7781465708085. Delta is -0.0009413119414602988
# WARNING:hmmlearn.base:Model is not converging.  Current: 2638.9887490069987 is not greater than 2639.019409785269. Delta is -0.030660778270430455
# WARNING:hmmlearn.base:Model is not converging.  Current: 2515.245212973311 is not greater than 2515.280326194383. Delta is -0.035113221072151646
# WARNING:hmmlearn.base:Model is not converging.  Current: 2638.988749006996 is not greater than 2639.0194097852755. Delta is -0.030660778279525402
# WARNING:hmmlearn.base:Model is not converging.  Current: 2515.245212973308 is not greater than 2515.2803261943895. Delta is -0.03511322108170134
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.623605965625 is not greater than 2409.633093272841. Delta is -0.009487307216204499
# WARNING:hmmlearn.base:Model is not converging.  Current: 2409.6236059656535 is not greater than 2409.6330932744045. Delta is -0.009487308750976808

# %%
best_params ={'n_components': 8, 'covariance_type': 'diag', 'random_state': 32}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# GaussianHMM(n_components=8, n_iter=100, random_state=32)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  3899.9616854560472
# MAPE:  17.882159684438825
# R-squared:  -2.983548128308724
# RMSE:  4387.9451989312865
#
# ** Validate **
# MAE:  5775.365805223397
# MAPE:  24.930825874750806
# R-squared:  -65.19771355601122
# RMSE:  6064.429245958687

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
