# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 1.7 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
# company_csv = '/content/drive/MyDrive/Colab Notebooks/VMD.csv'
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/VMD.csv'

df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02   5980   6240   5980   6240      50    VMD
# 1              1  2014-01-03   6240   6240   6240   6240     100    VMD
# 2              2  2014-01-06   6340   6340   6340   6340     860    VMD
# 3              3  2014-01-07   6340   6340   6340   6340       0    VMD
# 4              4  2014-01-08   6090   6340   6090   6340     200    VMD
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2472        2472  2023-12-04  20300  20300  19700  20300  238300    VMD
# 2473        2473  2023-12-05  20300  20900  19750  19900   62700    VMD
# 2474        2474  2023-12-06  20300  20600  20100  20150   51500    VMD
# 2475        2475  2023-12-07  20150  20300  20000  20150   41100    VMD
# 2476        2476  2023-12-08  20400  20400  20000  20050   62300    VMD
#
# [2477 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %%
# Split the data
train_size = int(0.6 * len(data))
test_size = int(0.3 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.435921883693 is not greater than 2974.5168192635765. Delta is -0.08089737988348134
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.4213479418836 is not greater than 2974.4455209716493. Delta is -0.0241730297657341
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.43194433279 is not greater than 2974.504936943279. Delta is -0.07299261048910921
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.424507029046 is not greater than 2974.4774169304187. Delta is -0.05290990137291374
# WARNING:hmmlearn.base:Model is not converging.  Current: 2966.9719544536583 is not greater than 2966.9859601521557. Delta is -0.01400569849738531
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.444554365092 is not greater than 2974.4874619552843. Delta is -0.0429075901924989
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.970108033758 is not greater than 2950.978946251001. Delta is -0.008838217243010149
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.968388054806 is not greater than 2950.9692440237327. Delta is -0.0008559689267713111
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.4353705933713 is not greater than 2974.513015175409. Delta is -0.07764458203746472
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.9688018197044 is not greater than 2950.9780281205644. Delta is -0.00922630086006393
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.4359218836908 is not greater than 2974.5168192635615. Delta is -0.08089737987074841
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.421347941866 is not greater than 2974.4455209716607. Delta is -0.02417302979483793
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.431944332798 is not greater than 2974.5049369432404. Delta is -0.07299261044227023
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.424507029055 is not greater than 2974.4774169304196. Delta is -0.052909901364728285
# WARNING:hmmlearn.base:Model is not converging.  Current: 2966.97195445365 is not greater than 2966.9859601521566. Delta is -0.014005698506480257
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.4445543651013 is not greater than 2974.487461955294. Delta is -0.0429075901924989
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.9701080337845 is not greater than 2950.978946250999. Delta is -0.008838217214361066
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.9683880548455 is not greater than 2950.969244023811. Delta is -0.0008559689654248359
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.43537059338 is not greater than 2974.513015175413. Delta is -0.07764458203291724
# WARNING:hmmlearn.base:Model is not converging.  Current: 2950.968801819709 is not greater than 2950.978028120548. Delta is -0.009226300839145551
# WARNING:hmmlearn.base:Model is not converging.  Current: 2901.5851197309757 is not greater than 2901.5857699214366. Delta is -0.0006501904608740006
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.882079823062 is not greater than 3669.8823726911232. Delta is -0.00029286806102390983
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.149299039817 is not greater than 3669.2265411782246. Delta is -0.07724213840765515
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.689649361894 is not greater than 3670.3106309853633. Delta is -0.6209816234691061
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.7313554670027 is not greater than 3669.876510054573. Delta is -0.14515458757023225
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.5099082770644 is not greater than 3668.523961710292. Delta is -0.01405343322767294
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.236918777152 is not greater than 3669.3551825430422. Delta is -0.11826376589033316
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.386519357561 is not greater than 2974.3867161860453. Delta is -0.00019682848414959153
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.513501166279 is not greater than 3669.822203426183. Delta is -0.30870225990383915
# WARNING:hmmlearn.base:Model is not converging.  Current: 2973.856392357097 is not greater than 2973.8711360588773. Delta is -0.014743701780389529
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.5949563832582 is not greater than 3669.9620381629793. Delta is -0.3670817797210475
# WARNING:hmmlearn.base:Model is not converging.  Current: 3645.783609522213 is not greater than 3645.8109557734647. Delta is -0.0273462512518563
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.4106462144214 is not greater than 3669.5313633548208. Delta is -0.12071714039939252
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.383385549423 is not greater than 2974.383985029439. Delta is -0.0005994800158077851
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.882079822902 is not greater than 3669.8823726910373. Delta is -0.000292868135147728
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.1492990399397 is not greater than 3669.2265411781286. Delta is -0.07724213818892167
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.689649361943 is not greater than 3670.310630985399. Delta is -0.6209816234559185
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.7313554670372 is not greater than 3669.8765100544856. Delta is -0.14515458744835996
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.509908276914 is not greater than 3668.5239617102707. Delta is -0.014053433356821188
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.2369187771565 is not greater than 3669.3551825429754. Delta is -0.11826376581893783
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.3865193575584 is not greater than 2974.3867161860494. Delta is -0.0001968284909708018
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.5135011661787 is not greater than 3669.822203426351. Delta is -0.3087022601721401
# WARNING:hmmlearn.base:Model is not converging.  Current: 2973.856392357099 is not greater than 2973.871136058873. Delta is -0.014743701774023066
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.594956383301 is not greater than 3669.9620381628656. Delta is -0.3670817795646144
# WARNING:hmmlearn.base:Model is not converging.  Current: 3645.783609522126 is not greater than 3645.8109557735293. Delta is -0.02734625140328717
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.4106462144505 is not greater than 3669.531363354704. Delta is -0.12071714025341862
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.3833855493854 is not greater than 2974.383985029476. Delta is -0.000599480090841098
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.625574416487 is not greater than 3585.626365296893. Delta is -0.0007908804059297836
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.6253075784316 is not greater than 3585.626565471596. Delta is -0.0012578931646203273
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.6255783192323 is not greater than 3585.6263946147. Delta is -0.0008162954677572998
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.6254944825446 is not greater than 3585.6264365100074. Delta is -0.0009420274627700564
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.62540253194 is not greater than 3585.626505716706. Delta is -0.0011031847661797656
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.6256128679292 is not greater than 3585.6263345090006. Delta is -0.0007216410713226651
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.6254840960582 is not greater than 3585.626495294215. Delta is -0.0010111981569025374
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.2004849215573 is not greater than 2974.219261846102. Delta is -0.01877692454490898
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.5889157400816 is not greater than 3670.6557471159012. Delta is -0.06683137581967458
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.3968308281605 is not greater than 3669.599023649784. Delta is -0.20219282162361196
# WARNING:hmmlearn.base:Model is not converging.  Current: 3666.506746259279 is not greater than 3666.548582907108. Delta is -0.041836647828858986
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.9095429907197 is not greater than 3667.254475437962. Delta is -1.3449324472421722
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.0139812387097 is not greater than 3669.234750620994. Delta is -0.22076938228428844
# WARNING:hmmlearn.base:Model is not converging.  Current: 3667.503828591748 is not greater than 3667.5852395053935. Delta is -0.08141091364541353
# WARNING:hmmlearn.base:Model is not converging.  Current: 2974.20048492156 is not greater than 2974.219261846109. Delta is -0.018776924549001706
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.5889157401484 is not greater than 3670.6557471160227. Delta is -0.06683137587424426
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.396830828165 is not greater than 3669.599023649785. Delta is -0.20219282161997398
# WARNING:hmmlearn.base:Model is not converging.  Current: 3666.506746259389 is not greater than 3666.5485829072286. Delta is -0.04183664783977292
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.9095429906797 is not greater than 3667.2544754378982. Delta is -1.3449324472185253
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.013981238583 is not greater than 3669.2347506209467. Delta is -0.22076938236386923
# WARNING:hmmlearn.base:Model is not converging.  Current: 3667.5038285917817 is not greater than 3667.5852395053507. Delta is -0.08141091356901597
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.7823574018307 is not greater than 3668.8343572159715. Delta is -0.05199981414079957
# WARNING:hmmlearn.base:Model is not converging.  Current: 3640.0755266009 is not greater than 3640.5235456459745. Delta is -0.44801904507448853
# WARNING:hmmlearn.base:Model is not converging.  Current: 2949.9149615856563 is not greater than 2949.9991896192582. Delta is -0.08422803360190301
# WARNING:hmmlearn.base:Model is not converging.  Current: 3666.906302711803 is not greater than 3667.0788317311058. Delta is -0.17252901930260123
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.198646144077 is not greater than 3665.650761759442. Delta is -0.4521156153650736
# WARNING:hmmlearn.base:Model is not converging.  Current: 3662.1956934259983 is not greater than 3662.408259272029. Delta is -0.21256584603088413
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.2610497131495 is not greater than 3669.3288807617. Delta is -0.06783104855048805
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.5439250090785 is not greater than 3670.6099725359204. Delta is -0.06604752684188497
# WARNING:hmmlearn.base:Model is not converging.  Current: 3216.0075461211122 is not greater than 3216.127216488838. Delta is -0.11967036772557549
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.782357401884 is not greater than 3668.8343572159706. Delta is -0.05199981408668464
# WARNING:hmmlearn.base:Model is not converging.  Current: 3640.0755266009764 is not greater than 3640.5235456460255. Delta is -0.4480190450490227
# WARNING:hmmlearn.base:Model is not converging.  Current: 2949.914961585663 is not greater than 2949.999189619266. Delta is -0.0842280336028125
# WARNING:hmmlearn.base:Model is not converging.  Current: 3666.9063027116867 is not greater than 3667.078831731217. Delta is -0.17252901953042965
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.1986461440392 is not greater than 3665.650761759465. Delta is -0.452115615425555
# WARNING:hmmlearn.base:Model is not converging.  Current: 3662.195693426047 is not greater than 3662.408259272007. Delta is -0.21256584595994354
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.261049713144 is not greater than 3669.3288807616623. Delta is -0.06783104851820099
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.5439250090926 is not greater than 3670.609972535901. Delta is -0.06604752680823367
# WARNING:hmmlearn.base:Model is not converging.  Current: 3216.0075461211163 is not greater than 3216.127216488831. Delta is -0.11967036771466155
# WARNING:hmmlearn.base:Model is not converging.  Current: 3585.632674614877 is not greater than 3585.633852231779. Delta is -0.0011776169021686655
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.2641076676755 is not greater than 3667.0630370570107. Delta is -1.7989293893351714
# WARNING:hmmlearn.base:Model is not converging.  Current: 3301.973019566935 is not greater than 3301.995258954893. Delta is -0.022239387958052248
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.9068185770593 is not greater than 3666.1375197624025. Delta is -0.23070118534315043
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.6650650023025 is not greater than 3668.9657857750535. Delta is -0.3007207727509922
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.4302416066207 is not greater than 3658.1718456936787. Delta is -0.7416040870580218
# WARNING:hmmlearn.base:Model is not converging.  Current: 4045.744807862298 is not greater than 4045.757624828309. Delta is -0.012816966011087061
# WARNING:hmmlearn.base:Model is not converging.  Current: 3639.6761586122175 is not greater than 3640.139037561311. Delta is -0.46287894909346505
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.6970953559853 is not greater than 3670.86175965876. Delta is -0.1646643027747814
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.264107667695 is not greater than 3667.063037057069. Delta is -1.798929389373825
# WARNING:hmmlearn.base:Model is not converging.  Current: 3301.973019566969 is not greater than 3301.995258954898. Delta is -0.022239387928948418
# WARNING:hmmlearn.base:Model is not converging.  Current: 3665.906818577049 is not greater than 3666.137519762415. Delta is -0.23070118536634254
# WARNING:hmmlearn.base:Model is not converging.  Current: 3668.66506500234 is not greater than 3668.9657857749958. Delta is -0.30072077265595
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.4302416066294 is not greater than 3658.1718456936924. Delta is -0.741604087063024
# WARNING:hmmlearn.base:Model is not converging.  Current: 4045.7448078622533 is not greater than 4045.7576248284004. Delta is -0.012816966147056519
# WARNING:hmmlearn.base:Model is not converging.  Current: 3639.6761586122443 is not greater than 3640.1390375613137. Delta is -0.46287894906936344
# WARNING:hmmlearn.base:Model is not converging.  Current: 3670.6970953560617 is not greater than 3670.8617596587233. Delta is -0.1646643026615493
# WARNING:hmmlearn.base:Model is not converging.  Current: 4035.762086007173 is not greater than 4036.094117452946. Delta is -0.33203144577328203
# WARNING:hmmlearn.base:Model is not converging.  Current: 3300.889525437271 is not greater than 3300.9303657236846. Delta is -0.04084028641364057
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.298581902676 is not greater than 3657.671937896065. Delta is -0.37335599338939573
# WARNING:hmmlearn.base:Model is not converging.  Current: 3301.1372344878246 is not greater than 3301.260027809346. Delta is -0.12279332152138522
# WARNING:hmmlearn.base:Model is not converging.  Current: 3661.926403050367 is not greater than 3661.9333710859223. Delta is -0.006968035555473762
# WARNING:hmmlearn.base:Model is not converging.  Current: 4035.762086007149 is not greater than 4036.0941174529175. Delta is -0.33203144576873456
# WARNING:hmmlearn.base:Model is not converging.  Current: 3300.889525437265 is not greater than 3300.93036572372. Delta is -0.04084028645502258
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.2985819027804 is not greater than 3657.6719378960306. Delta is -0.37335599325024305
# WARNING:hmmlearn.base:Model is not converging.  Current: 3301.13723448782 is not greater than 3301.2600278093555. Delta is -0.12279332153548239
# WARNING:hmmlearn.base:Model is not converging.  Current: 3661.926403050417 is not greater than 3661.9333710859883. Delta is -0.006968035571389919
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.1761739939097 is not greater than 3657.9283785511907. Delta is -0.7522045572809475
# WARNING:hmmlearn.base:Model is not converging.  Current: 3663.7519287579125 is not greater than 3664.517487081492. Delta is -0.7655583235796257
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.254570081697 is not greater than 3669.308218423923. Delta is -0.053648342226097157
# WARNING:hmmlearn.base:Model is not converging.  Current: 3657.1761739941435 is not greater than 3657.9283785727507. Delta is -0.752204578607234
# WARNING:hmmlearn.base:Model is not converging.  Current: 3663.751928757917 is not greater than 3664.5174870825554. Delta is -0.7655583246382776
# WARNING:hmmlearn.base:Model is not converging.  Current: 3669.25457008171 is not greater than 3669.308218423902. Delta is -0.053648342191991105
# WARNING:hmmlearn.base:Model is not converging.  Current: 3663.254648886972 is not greater than 3663.4342303610815. Delta is -0.17958147410945458
# WARNING:hmmlearn.base:Model is not converging.  Current: 3650.789550706918 is not greater than 3650.812831892989. Delta is -0.023281186071017146
# WARNING:hmmlearn.base:Model is not converging.  Current: 4035.1669057475815 is not greater than 4035.457651307185. Delta is -0.2907455596036925
# WARNING:hmmlearn.base:Model is not converging.  Current: 3664.851804408311 is not greater than 3665.1542308304583. Delta is -0.302426422147164
# WARNING:hmmlearn.base:Model is not converging.  Current: 3674.565006675484 is not greater than 3674.771798306793. Delta is -0.20679163130898814
# WARNING:hmmlearn.base:Model is not converging.  Current: 3655.08675628593 is not greater than 3656.309679053804. Delta is -1.2229227678740244
# WARNING:hmmlearn.base:Model is not converging.  Current: 3663.2546488869484 is not greater than 3663.434230361034. Delta is -0.1795814740858077
# WARNING:hmmlearn.base:Model is not converging.  Current: 3650.7895507069466 is not greater than 3650.8128318929985. Delta is -0.023281186051917757
# WARNING:hmmlearn.base:Model is not converging.  Current: 4035.166905747534 is not greater than 4035.4576513071515. Delta is -0.29074555961733495
# WARNING:hmmlearn.base:Model is not converging.  Current: 3664.8518044082607 is not greater than 3665.154230830488. Delta is -0.3024264222271995
# WARNING:hmmlearn.base:Model is not converging.  Current: 3674.565006677725 is not greater than 3674.7717983044536. Delta is -0.20679162672877283
# WARNING:hmmlearn.base:Model is not converging.  Current: 3655.086756285826 is not greater than 3656.3096790538248. Delta is -1.2229227679986252

# %%
best_params ={'n_components': 8, 'covariance_type': 'full', 'random_state': 44}
# {'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# GaussianHMM(covariance_type='full', n_components=8, n_iter=100, random_state=44)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  6136.134069078006
# MAPE:  20.85197031114501
# R-squared:  -0.19316577102858568
# RMSE:  9964.968093408681
#
# ** Validate **
# MAE:  3659.771704047599
# MAPE:  16.78617948157955
# R-squared:  -1.498703275032938
# RMSE:  4318.224019055665

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
