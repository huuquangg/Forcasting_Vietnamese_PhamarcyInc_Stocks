# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 5.4 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/IMP.csv'
# company_csv = '/content/drive/MyDrive/Colab Notebooks/VMD.csv'

df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02  10760  10790  10760  10790    2410    IMP
# 1              1  2014-01-03  10760  10840  10670  10840   13010    IMP
# 2              2  2014-01-06  10870  11560  10870  11540   55630    IMP
# 3              3  2014-01-07  11400  11540  11330  11540   20980    IMP
# 4              4  2014-01-08  11370  11830  11330  11800   43410    IMP
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2462        2462  2023-12-04  54700  55500  54400  55300   24800    IMP
# 2463        2463  2023-12-05  55200  55200  54600  55000   10200    IMP
# 2464        2464  2023-12-06  55000  55200  54900  55200   26600    IMP
# 2465        2465  2023-12-07  54900  55900  54900  55200   29200    IMP
# 2466        2466  2023-12-08  55200  55200  54500  55200    6300    IMP
#
# [2467 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %%
# Split the data
train_size = int(0.6 * len(data))
test_size = int(0.3 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512492930843 is not greater than 2689.0520486529394. Delta is -0.0007993598551365722
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0510925073313 is not greater than 2689.051697499276. Delta is -0.0006049919447832508
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051212799298 is not greater than 2689.052140905498. Delta is -0.000928106200262846
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511101200955 is not greater than 2689.051832273456. Delta is -0.0007221533605843433
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511629561624 is not greater than 2689.0520899780868. Delta is -0.0009270219243262545
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512096925922 is not greater than 2689.052143600824. Delta is -0.0009339082316728309
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512117929575 is not greater than 2689.052141866078. Delta is -0.0009300731203438772
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051223157887 is not greater than 2689.0521261453355. Delta is -0.0009029874486259359
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511836646833 is not greater than 2689.052135617971. Delta is -0.0009519532877675374
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051182922519 is not greater than 2689.0521269943024. Delta is -0.0009440717835786927
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051212263707 is not greater than 2689.0521414260966. Delta is -0.0009291623896388046
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511932636155 is not greater than 2689.0521431057236. Delta is -0.0009498421081843844
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051203240335 is not greater than 2689.0521465767465. Delta is -0.0009433364116375742
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512604276787 is not greater than 2689.0519978060065. Delta is -0.0007373783278126211
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511421240767 is not greater than 2689.052013770696. Delta is -0.000871646619089006
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051181511757 is not greater than 2689.052132494336. Delta is -0.0009509825790701143
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512216085053 is not greater than 2689.0521268264224. Delta is -0.0009052179170794261
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051102651216 is not greater than 2689.0517788653865. Delta is -0.0006762141706531111
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051313756869 is not greater than 2689.0515964504857. Delta is -0.0002826936165547522
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.05106740665 is not greater than 2689.0514596601674. Delta is -0.0003922535174751829
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511903877423 is not greater than 2689.0521384998233. Delta is -0.0009481120810050925
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051249293089 is not greater than 2689.0520486529476. Delta is -0.000799359858774551
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0510925073286 is not greater than 2689.051697499277. Delta is -0.0006049919484212296
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512127992956 is not greater than 2689.0521409055177. Delta is -0.0009281062220907188
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051110120096 is not greater than 2689.051832273463. Delta is -0.0007221533669508062
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.05116295616 is not greater than 2689.0520899780863. Delta is -0.0009270219261452439
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512096926086 is not greater than 2689.052143600833. Delta is -0.0009339082243968733
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051211792958 is not greater than 2689.05214186609. Delta is -0.0009300731321673084
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051223157879 is not greater than 2689.052126145346. Delta is -0.00090298746681583
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511836647047 is not greater than 2689.052135617962. Delta is -0.0009519532572994649
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511829225097 is not greater than 2689.0521269942997. Delta is -0.0009440717899451556
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051212263728 is not greater than 2689.0521414260975. Delta is -0.0009291623696299212
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511932636377 is not greater than 2689.0521431057205. Delta is -0.0009498420827185328
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512032403185 is not greater than 2689.052146576723. Delta is -0.0009433364043616166
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051260427669 is not greater than 2689.051997806018. Delta is -0.0007373783487309993
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511421240817 is not greater than 2689.0520137707117. Delta is -0.0008716466300029424
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511815117407 is not greater than 2689.052132494328. Delta is -0.0009509825872555666
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0512216084885 is not greater than 2689.0521268264188. Delta is -0.0009052179302670993
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511026512613 is not greater than 2689.0517788653897. Delta is -0.0006762141283616074
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0513137568614 is not greater than 2689.051596450478. Delta is -0.0002826936165547522
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.051067406659 is not greater than 2689.0514596601615. Delta is -0.0003922535024685203
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0511903877336 is not greater than 2689.0521384998224. Delta is -0.0009481120887357974
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739233708902 is not greater than 2682.739239837399. Delta is -6.128497261670418e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739233615664 is not greater than 2682.739238645714. Delta is -5.030050033383304e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.7392338273853 is not greater than 2682.7392464178715. Delta is -1.259048622159753e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739234028706 is not greater than 2682.739244069604. Delta is -1.0040897905128077e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739233689911 is not greater than 2682.7392430191585. Delta is -9.329247404821217e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739233697283 is not greater than 2682.7392419724733. Delta is -8.275190339190885e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.7392339205016 is not greater than 2682.739251550217. Delta is -1.7629715330258477e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739233657423 is not greater than 2682.739240371939. Delta is -6.714516075589927e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.7392337060965 is not greater than 2682.7392425734224. Delta is -8.867325959727168e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.7392336251837 is not greater than 2682.739238528328. Delta is -4.90314414491877e-06
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9563316479603 is not greater than 3042.959741546507. Delta is -0.0034098985465789156
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.958199236178 is not greater than 3042.9643772400054. Delta is -0.006178003827244538
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.994278216167 is not greater than 2688.995312062638. Delta is -0.0010338464708183892
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9563531024387 is not greater than 3042.959634667873. Delta is -0.0032815654344631184
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.956907189326 is not greater than 3042.9586895351936. Delta is -0.0017823458674683934
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.030348414876 is not greater than 2689.0308279148517. Delta is -0.0004794999758814811
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.970560094826 is not greater than 2688.9715297750927. Delta is -0.0009696802667349402
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957931884346 is not greater than 3042.959845079882. Delta is -0.0019131955359625863
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.7960503898667 is not greater than 3046.833502463325. Delta is -0.03745207345855306
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.80306243697 is not greater than 3046.8571661825936. Delta is -0.054103745623706345
# WARNING:hmmlearn.base:Model is not converging.  Current: 2903.103890638369 is not greater than 2903.104953204251. Delta is -0.001062565881966293
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.998501082774 is not greater than 2689.0028559416. Delta is -0.004354858825990959
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0254388825315 is not greater than 2689.025824036806. Delta is -0.00038515427468155394
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0262612312463 is not greater than 2689.026631754691. Delta is -0.000370523444871651
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.011018912135 is not greater than 2689.017404458333. Delta is -0.006385546198089287
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.7895711867827 is not greater than 3046.8224565476894. Delta is -0.03288536090667549
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9576426110507 is not greater than 3042.9604902844626. Delta is -0.002847673411906726
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957215846618 is not greater than 3042.9604635044993. Delta is -0.0032476578812747903
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957198105139 is not greater than 3042.9604801463647. Delta is -0.0032820412257024145
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9563316479166 is not greater than 3042.9597415465005. Delta is -0.0034098985838681983
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.958199236222 is not greater than 3042.9643772399745. Delta is -0.006178003752665973
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.9942782161597 is not greater than 2688.9953120626446. Delta is -0.001033846484915557
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9563531024564 is not greater than 3042.95963466789. Delta is -0.0032815654335536237
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9569071893343 is not greater than 3042.9586895351554. Delta is -0.0017823458210841636
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0303484149094 is not greater than 2689.030827914835. Delta is -0.00047949992540452513
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.9705600948664 is not greater than 2688.971529775084. Delta is -0.0009696802176222263
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957931884304 is not greater than 3042.9598450798653. Delta is -0.001913195561428438
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.796050389826 is not greater than 3046.8335024633066. Delta is -0.03745207348038093
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.8030624369762 is not greater than 3046.857166182591. Delta is -0.0541037456146114
# WARNING:hmmlearn.base:Model is not converging.  Current: 2903.1038906382028 is not greater than 2903.1049532042566. Delta is -0.0010625660538607917
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.998501082769 is not greater than 2689.0028559416196. Delta is -0.004354858850547316
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0254388825533 is not greater than 2689.0258240368003. Delta is -0.00038515424694196554
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.026261231244 is not greater than 2689.0266317547635. Delta is -0.00037052351945021655
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.0110189121356 is not greater than 2689.0174044583227. Delta is -0.0063855461871753505
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.7895711867914 is not greater than 3046.8224565476667. Delta is -0.03288536087529792
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.9576426110707 is not greater than 3042.960490284497. Delta is -0.002847673426458641
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957215846612 is not greater than 3042.9604635044952. Delta is -0.0032476578830937797
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.957198105151 is not greater than 3042.960480146328. Delta is -0.003282041177044448
# WARNING:hmmlearn.base:Model is not converging.  Current: 2682.739848140438 is not greater than 2682.7398650984674. Delta is -1.6958029391389573e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.782922630564 is not greater than 2688.7832656045694. Delta is -0.00034297400543437107
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.750534900283 is not greater than 3046.7776824268667. Delta is -0.02714752658357611
# WARNING:hmmlearn.base:Model is not converging.  Current: 3057.0622181892486 is not greater than 3057.072051932244. Delta is -0.009833742995397188
# WARNING:hmmlearn.base:Model is not converging.  Current: 2975.2573397340916 is not greater than 2975.288348677025. Delta is -0.031008942933567596
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.44187097098 is not greater than 3042.4545401705072. Delta is -0.012669199527408637
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.987936637746 is not greater than 2688.9903715990845. Delta is -0.002434961338622088
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.6261085459187 is not greater than 3046.6446086459505. Delta is -0.018500100031815236
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.8155846216737 is not greater than 3042.8292791314116. Delta is -0.013694509737888438
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.084909611156 is not greater than 2689.1171696256124. Delta is -0.03226001445636939
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.6911756389395 is not greater than 3042.695172760995. Delta is -0.00399712205535252
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.6597638714225 is not greater than 3042.702616179081. Delta is -0.04285230765844972
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.966431469369 is not greater than 2688.96815955443. Delta is -0.0017280850606766762
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.782922630521 is not greater than 2688.7832656045885. Delta is -0.0003429740672800108
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.750534900295 is not greater than 3046.777682426855. Delta is -0.027147526559929247
# WARNING:hmmlearn.base:Model is not converging.  Current: 3057.0622181892563 is not greater than 3057.0720519321167. Delta is -0.009833742860337225
# WARNING:hmmlearn.base:Model is not converging.  Current: 2975.257339734064 is not greater than 2975.288348677029. Delta is -0.031008942964945163
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.4418709709994 is not greater than 3042.4545401706127. Delta is -0.012669199613355886
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.987936637761 is not greater than 2688.9903715991068. Delta is -0.0024349613458980457
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.62610854604 is not greater than 3046.6446086460114. Delta is -0.01850009997133384
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.8155846216678 is not greater than 3042.829279131475. Delta is -0.013694509807010036
# WARNING:hmmlearn.base:Model is not converging.  Current: 2689.08490961115 is not greater than 2689.117169625657. Delta is -0.032260014506846346
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.691175638925 is not greater than 3042.6951727609885. Delta is -0.003997122063537972
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.6597638714456 is not greater than 3042.702616179049. Delta is -0.04285230760342529
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.966431469334 is not greater than 2688.9681595544507. Delta is -0.0017280851166106004
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.196479904778 is not greater than 3042.197306934141. Delta is -0.000827029363335896
# WARNING:hmmlearn.base:Model is not converging.  Current: 3368.9657210172913 is not greater than 3368.9914392847713. Delta is -0.025718267479987844
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.453827979182 is not greater than 3046.499000600283. Delta is -0.04517262110130105
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.5585251000803 is not greater than 3046.5823857444425. Delta is -0.023860644362230232
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.696698790942 is not greater than 3045.7663427372663. Delta is -0.06964394632450421
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.8496541469017 is not greater than 2688.8574666922254. Delta is -0.007812545323758968
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.4987373937606 is not greater than 3042.507822535434. Delta is -0.009085141673494945
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.3584246823134 is not greater than 3045.4937473128953. Delta is -0.135322630581868
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.1964799047673 is not greater than 3042.197306934151. Delta is -0.0008270293837995268
# WARNING:hmmlearn.base:Model is not converging.  Current: 3368.9657210172845 is not greater than 3368.9914392847904. Delta is -0.025718267505908443
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.453827979184 is not greater than 3046.499000600279. Delta is -0.045172621094934584
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.558525100013 is not greater than 3046.582385744539. Delta is -0.02386064452593928
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.6966987907763 is not greater than 3045.766342737252. Delta is -0.06964394647593508
# WARNING:hmmlearn.base:Model is not converging.  Current: 2688.849654146908 is not greater than 2688.8574666922373. Delta is -0.007812545329215936
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.4987373937606 is not greater than 3042.5078225354364. Delta is -0.009085141675768682
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.3584246822998 is not greater than 3045.4937473128875. Delta is -0.1353226305877797
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.309909993606 is not greater than 3046.336519819356. Delta is -0.02660982574980153
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.6495634189228 is not greater than 3042.6635712130305. Delta is -0.014007794107783411
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.553885920169 is not greater than 3042.590373128994. Delta is -0.03648720882529233
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.0820932813403 is not greater than 3042.124498080696. Delta is -0.0424047993556087
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.912516082401 is not greater than 3045.9188873113944. Delta is -0.0063712289934301225
# WARNING:hmmlearn.base:Model is not converging.  Current: 3466.286916157144 is not greater than 3466.4787294685416. Delta is -0.19181331139770919
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.7443147621875 is not greater than 3041.8105895536964. Delta is -0.06627479150893123
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.7872900881407 is not greater than 3041.801742589507. Delta is -0.014452501366122306
# WARNING:hmmlearn.base:Model is not converging.  Current: 3046.309909993579 is not greater than 3046.3365198193237. Delta is -0.02660982574479931
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.649563418915 is not greater than 3042.663571213023. Delta is -0.014007794107783411
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.55388592016 is not greater than 3042.5903731290064. Delta is -0.036487208846210706
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.0820932813367 is not greater than 3042.124498080694. Delta is -0.04240479935742769
# WARNING:hmmlearn.base:Model is not converging.  Current: 3045.9125160823974 is not greater than 3045.918887311401. Delta is -0.006371229003434564
# WARNING:hmmlearn.base:Model is not converging.  Current: 3466.2869161606986 is not greater than 3466.4787294588223. Delta is -0.191813298123634
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.74431476218 is not greater than 3041.8105895536937. Delta is -0.06627479151393345
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.787290088123 is not greater than 3041.8017425894964. Delta is -0.014452501373398263
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.916062434752 is not greater than 3041.919211650515. Delta is -0.003149215763187385
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.041130165861 is not greater than 3042.068880552444. Delta is -0.027750386583193176
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.9530361891902 is not greater than 3042.029757184545. Delta is -0.07672099535466259
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.9160624347633 is not greater than 3041.9192116505033. Delta is -0.0031492157399952703
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.0411301658523 is not greater than 3042.0688805524896. Delta is -0.02775038663730811
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.95303618915 is not greater than 3042.0297571846254. Delta is -0.07672099547517064
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.1464043098113 is not greater than 3041.182856973565. Delta is -0.03645266375360734
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.7025750915277 is not greater than 3041.7392235267007. Delta is -0.03664843517299232
# WARNING:hmmlearn.base:Model is not converging.  Current: 3368.481956841617 is not greater than 3368.519706995336. Delta is -0.0377501537191165
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.1464043098044 is not greater than 3041.1828569735494. Delta is -0.03645266374496714
# WARNING:hmmlearn.base:Model is not converging.  Current: 3041.702575091536 is not greater than 3041.7392235267193. Delta is -0.03664843518345151
# WARNING:hmmlearn.base:Model is not converging.  Current: 3368.481956841622 is not greater than 3368.5197069953506. Delta is -0.03775015372866619
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.2154610430675 is not greater than 3042.2285293381383. Delta is -0.013068295070752356
# WARNING:hmmlearn.base:Model is not converging.  Current: 3470.511493691907 is not greater than 3470.547503502794. Delta is -0.03600981088675326
# WARNING:hmmlearn.base:Model is not converging.  Current: 3447.244226874324 is not greater than 3447.304184160214. Delta is -0.059957285890050116
# WARNING:hmmlearn.base:Model is not converging.  Current: 3042.2154610430566 is not greater than 3042.2285293381124. Delta is -0.013068295055745693
# WARNING:hmmlearn.base:Model is not converging.  Current: 3470.511493691949 is not greater than 3470.547503502704. Delta is -0.036009810754876526
# WARNING:hmmlearn.base:Model is not converging.  Current: 3447.244226874348 is not greater than 3447.304184160225. Delta is -0.05995728587686244

# %%
best_params ={'n_components': 8, 'covariance_type': 'full', 'random_state': 97}
# {'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 3461.6019352954618 is not greater than 3461.6196590354225. Delta is -0.01772373996072929
# GaussianHMM(covariance_type='full', n_components=8, n_iter=100, random_state=97)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  20096.21848009202
# MAPE:  33.58419192986861
# R-squared:  -2.2705483076337556
# RMSE:  23104.03541081288
#
# ** Validate **
# MAE:  21731.130790744006
# MAPE:  37.806274617251475
# R-squared:  -10.246878389884175
# RMSE:  22679.50773281497

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
