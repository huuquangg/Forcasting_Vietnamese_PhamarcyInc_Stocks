# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 3.4 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/IMP.csv'
# company_csv = '/content/drive/MyDrive/Colab Notebooks/VMD.csv'

df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02  10760  10790  10760  10790    2410    IMP
# 1              1  2014-01-03  10760  10840  10670  10840   13010    IMP
# 2              2  2014-01-06  10870  11560  10870  11540   55630    IMP
# 3              3  2014-01-07  11400  11540  11330  11540   20980    IMP
# 4              4  2014-01-08  11370  11830  11330  11800   43410    IMP
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2462        2462  2023-12-04  54700  55500  54400  55300   24800    IMP
# 2463        2463  2023-12-05  55200  55200  54600  55000   10200    IMP
# 2464        2464  2023-12-06  55000  55200  54900  55200   26600    IMP
# 2465        2465  2023-12-07  54900  55900  54900  55200   29200    IMP
# 2466        2466  2023-12-08  55200  55200  54500  55200    6300    IMP
#
# [2467 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %%
# Split the data
train_size = int(0.7 * len(data))
test_size = int(0.2 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9683235180523 is not greater than 2746.9711930499143. Delta is -0.00286953186196115
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9700495582997 is not greater than 2746.9702311563333. Delta is -0.00018159803357775672
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9684934542456 is not greater than 2746.972039614734. Delta is -0.003546160488440364
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9682556440443 is not greater than 2746.970504985563. Delta is -0.0022493415185635968
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9681694002993 is not greater than 2746.9694616890442. Delta is -0.0012922887449349219
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.96811986839 is not greater than 2746.968851686714. Delta is -0.0007318183238567144
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.968087079026 is not greater than 2746.9684207013206. Delta is -0.00033362229441991076
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9683235180596 is not greater than 2746.971193049913. Delta is -0.00286953185332095
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9700495583006 is not greater than 2746.9702311563474. Delta is -0.0001815980467654299
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.968493454243 is not greater than 2746.9720396147336. Delta is -0.003546160490714101
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.968255644015 is not greater than 2746.970504985559. Delta is -0.0022493415440294484
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.968169400296 is not greater than 2746.969461689052. Delta is -0.0012922887558488583
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9681198684043 is not greater than 2746.9688516867122. Delta is -0.0007318183079405571
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9680870790235 is not greater than 2746.968420701332. Delta is -0.00033362230851707864
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.052039757783 is not greater than 3056.0637706189655. Delta is -0.011730861182513763
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.923226133896 is not greater than 2746.952884515413. Delta is -0.029658381517037924
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.049566105363 is not greater than 3056.058952419923. Delta is -0.009386314560288156
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0532399808944 is not greater than 3056.062464787864. Delta is -0.009224806969541532
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.924120735727 is not greater than 2746.9273943105654. Delta is -0.003273574838658533
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9160344176753 is not greater than 2746.9360606329337. Delta is -0.02002621525844006
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0559552406917 is not greater than 3056.059099843018. Delta is -0.0031446023263015377
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.052039757808 is not greater than 3056.0637706189827. Delta is -0.011730861174783058
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.923226133891 is not greater than 2746.952884515407. Delta is -0.029658381515673682
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0495661054156 is not greater than 3056.0589524199568. Delta is -0.009386314541188767
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.053239980873 is not greater than 3056.0624647878562. Delta is -0.009224806983183953
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.924120735723 is not greater than 2746.927394310555. Delta is -0.0032735748318373226
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9160344176803 is not greater than 2746.9360606329346. Delta is -0.020026215254347335
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0559552406853 is not greater than 3056.0590998429648. Delta is -0.0031446022794625605
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9540351232104 is not greater than 2746.9545513679686. Delta is -0.0005162447582733876
# WARNING:hmmlearn.base:Model is not converging.  Current: 3608.829361173549 is not greater than 3608.840275015544. Delta is -0.010913841995261464
# WARNING:hmmlearn.base:Model is not converging.  Current: 2747.843323647324 is not greater than 2747.8674208057246. Delta is -0.024097158400763874
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.9217211492914 is not greater than 2746.936464616237. Delta is -0.0147434669456743
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0371236355686 is not greater than 3056.046823871884. Delta is -0.009700236315438815
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.954035123306 is not greater than 2746.9545513679145. Delta is -0.0005162446086615091
# WARNING:hmmlearn.base:Model is not converging.  Current: 3608.8293611736153 is not greater than 3608.840275015583. Delta is -0.010913841967521876
# WARNING:hmmlearn.base:Model is not converging.  Current: 2747.843323647321 is not greater than 2747.8674208057546. Delta is -0.024097158433505683
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.921721149303 is not greater than 2746.9364646162426. Delta is -0.014743466939762584
# WARNING:hmmlearn.base:Model is not converging.  Current: 3056.0371236355795 is not greater than 3056.046823871895. Delta is -0.009700236315438815
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.8495693570026 is not greater than 2746.8542180412333. Delta is -0.00464868423068765
# WARNING:hmmlearn.base:Model is not converging.  Current: 2746.8495693570076 is not greater than 2746.854218041241. Delta is -0.004648684233416134
# WARNING:hmmlearn.base:Model is not converging.  Current: 3536.9264814407647 is not greater than 3537.314250061474. Delta is -0.38776862070926654
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.6168651707108 is not greater than 3055.6544617887093. Delta is -0.037596617998588044
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.455251403289 is not greater than 3055.530868135711. Delta is -0.0756167324220769
# WARNING:hmmlearn.base:Model is not converging.  Current: 3214.537357413774 is not greater than 3214.5424059767224. Delta is -0.005048562948559265
# WARNING:hmmlearn.base:Model is not converging.  Current: 3536.9264814406833 is not greater than 3537.3142500616136. Delta is -0.38776862093027376
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.6168651707176 is not greater than 3055.6544617887084. Delta is -0.03759661799085734
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.4552514032844 is not greater than 3055.5308681356855. Delta is -0.07561673240115852
# WARNING:hmmlearn.base:Model is not converging.  Current: 3214.53735741381 is not greater than 3214.5424059767543. Delta is -0.005048562944466539
# WARNING:hmmlearn.base:Model is not converging.  Current: 3608.774457330521 is not greater than 3608.894927270675. Delta is -0.12046994015418022
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.4355881261413 is not greater than 3055.4967644888707. Delta is -0.06117636272938398
# WARNING:hmmlearn.base:Model is not converging.  Current: 3608.77445733058 is not greater than 3608.894927270782. Delta is -0.1204699402019287
# WARNING:hmmlearn.base:Model is not converging.  Current: 3055.4355881261376 is not greater than 3055.49676448887. Delta is -0.06117636273256721
# WARNING:hmmlearn.base:Model is not converging.  Current: 3602.224933222877 is not greater than 3602.3340556240123. Delta is -0.10912240113520966
# WARNING:hmmlearn.base:Model is not converging.  Current: 3602.2249332229476 is not greater than 3602.334055625914. Delta is -0.10912240296647724

# %%
best_params ={'n_components': 7, 'covariance_type': 'tied', 'random_state': 43}
# {'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# GaussianHMM(covariance_type='tied', n_components=7, n_iter=100, random_state=43)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  25651.172568463702
# MAPE:  40.751748936044436
# R-squared:  -12.229198278976547
# RMSE:  26204.521145226165
#
# ** Validate **
# MAE:  19778.656924062638
# MAPE:  34.14643750829161
# R-squared:  -8.81585242175984
# RMSE:  21160.83398166475

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
