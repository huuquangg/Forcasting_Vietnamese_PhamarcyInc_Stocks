# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install matplotlib --quiet
# !pip install hmmlearn --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.4/160.4 kB 1.5 MB/s eta 0:00:00

# %%
# Import libraries for data manipulation and analysis
import numpy as np
import pandas as pd
from hmmlearn.hmm import GaussianHMM
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error, mean_absolute_error,r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_r_squared = r2_score(test,pred)
  print('R-squared: ', test_r_squared)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_r_squared = r2_score(val, pred_val)
  print('R-squared: ', val_r_squared)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
# 2. Đọc file csv
# company_csv = '/content/drive/MyDrive/Colab Notebooks/VMD.csv'
company_csv = '/content/drive/MyDrive/Colab Notebooks/Datacrawl/VMD.csv'

df = pd.read_csv(company_csv)
df
# Out:
#       Unnamed: 0        time   open   high    low  close  volume ticker
# 0              0  2014-01-02   5980   6240   5980   6240      50    VMD
# 1              1  2014-01-03   6240   6240   6240   6240     100    VMD
# 2              2  2014-01-06   6340   6340   6340   6340     860    VMD
# 3              3  2014-01-07   6340   6340   6340   6340       0    VMD
# 4              4  2014-01-08   6090   6340   6090   6340     200    VMD
# ...          ...         ...    ...    ...    ...    ...     ...    ...
# 2472        2472  2023-12-04  20300  20300  19700  20300  238300    VMD
# 2473        2473  2023-12-05  20300  20900  19750  19900   62700    VMD
# 2474        2474  2023-12-06  20300  20600  20100  20150   51500    VMD
# 2475        2475  2023-12-07  20150  20300  20000  20150   41100    VMD
# 2476        2476  2023-12-08  20400  20400  20000  20050   62300    VMD
#
# [2477 rows x 8 columns]

# %%
# Create a MinMaxScaler object with a specified range
scaler = MinMaxScaler()
data = scaler.fit_transform(np.array(df["close"]).reshape(-1, 1)) #chuan hoa data

# %% [markdown]
# # Spilt Dataset (7-2-1)
#
# ---

# %%
# Split the data
train_size = int(0.7 * len(data))
test_size = int(0.2 * len(data))
val_size = len(data) - train_size - test_size

train_data = data[:train_size]
test_data = data[train_size:train_size+test_size]
val_data = data[train_size+test_size:]

# %%
# ~10p
lowest_mse = 1
best_params = {}

for n_components in [2, 3, 4, 5, 6, 7, 8, 9]:
    for covariance_type in ["diag", "full", "tied"]:
      for i in range(1, 100):
        model = GaussianHMM(n_components=n_components, covariance_type=covariance_type, random_state = i)
        model.fit(train_data)
        y_pred, _ = model.sample(len(test_data))
        mse = mean_squared_error(test_data, y_pred.reshape(-1,1))
        # print("comp="+str(n_components) + ",type=" +str(covariance_type))

        # Update the best parameters if the score improves
        if mse < lowest_mse :
            lowest_mse = mse
            best_params = {
                "n_components": n_components,
                "covariance_type": covariance_type,
                "random_state": i
            }
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1049518193718 is not greater than 3523.109353846351. Delta is -0.004402026979278162
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1216243111094 is not greater than 3523.207819041283. Delta is -0.08619473017370183
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3375849631125 is not greater than 3521.3384960546723. Delta is -0.0009110915598284919
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.12185712652 is not greater than 3523.2077089665468. Delta is -0.08585184002686219
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.112969696753 is not greater than 3523.167508985577. Delta is -0.054539288823889365
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1243252154622 is not greater than 3523.2158050329067. Delta is -0.09147981744445133
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.337492973539 is not greater than 3521.338591781062. Delta is -0.0010988075227942318
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.337443707717 is not greater than 3521.3385673615853. Delta is -0.0011236538684897823
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.120755386085 is not greater than 3523.2055529404865. Delta is -0.08479755440157533
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.337634141357 is not greater than 3521.3385061665676. Delta is -0.0008720252108105342
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1049518193986 is not greater than 3523.109353846344. Delta is -0.004402026945626858
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1216243110907 is not greater than 3523.2078190413085. Delta is -0.08619473021781232
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3375849631107 is not greater than 3521.338496054668. Delta is -0.0009110915575547551
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1218571265326 is not greater than 3523.2077089666027. Delta is -0.08585184007006319
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1129696967537 is not greater than 3523.1675089855753. Delta is -0.05453928882161563
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.124325215458 is not greater than 3523.2158050329117. Delta is -0.09147981745354627
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3374929735332 is not greater than 3521.338591781068. Delta is -0.001098807534617663
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3374437076086 is not greater than 3521.338567361504. Delta is -0.001123653895319876
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.1207553860527 is not greater than 3523.205552940486. Delta is -0.08479755443340764
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3376341413546 is not greater than 3521.338506166565. Delta is -0.0008720252103557868
# WARNING:hmmlearn.base:Model is not converging.  Current: 3461.554395659304 is not greater than 3461.554697510666. Delta is -0.0003018513616552809
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.901567721489 is not greater than 4233.957195546464. Delta is -0.055627824975090334
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.037904306876 is not greater than 4234.409533291988. Delta is -0.37162898511178355
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.173028785562 is not greater than 3521.180629426863. Delta is -0.007600641300996358
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.184301177104 is not greater than 4234.304559290103. Delta is -0.12025811299827183
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.759660820396 is not greater than 4233.892013591153. Delta is -0.13235277075727936
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.262113230317 is not greater than 4233.431884526625. Delta is -0.16977129630868149
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.3042735813256 is not greater than 3521.3043609329693. Delta is -8.735164374229498e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.330546311577 is not greater than 4233.372864758299. Delta is -0.04231844672267471
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.0749530985836 is not greater than 3523.111026949418. Delta is -0.03607385083432746
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.089330237266 is not greater than 3523.164300732604. Delta is -0.0749704953377659
# WARNING:hmmlearn.base:Model is not converging.  Current: 3522.472746504221 is not greater than 3522.6478423903654. Delta is -0.17509588614439053
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.264106956537 is not greater than 4233.416592857042. Delta is -0.1524859005048711
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.901567721396 is not greater than 4233.957195546502. Delta is -0.05562782510605757
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.037904306868 is not greater than 4234.409533292108. Delta is -0.3716289852400223
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.173028785542 is not greater than 3521.180629426885. Delta is -0.007600641342833114
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.184301177164 is not greater than 4234.304559290022. Delta is -0.12025811285730015
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.759660820367 is not greater than 4233.892013591139. Delta is -0.13235277077274077
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.262113230256 is not greater than 4233.431884526655. Delta is -0.16977129639963096
# WARNING:hmmlearn.base:Model is not converging.  Current: 3521.304273581338 is not greater than 3521.30436093298. Delta is -8.735164237805293e-05
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.330546311611 is not greater than 4233.372864758281. Delta is -0.042318446669924015
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.0749530985468 is not greater than 3523.111026949395. Delta is -0.03607385084842463
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.089330237273 is not greater than 3523.164300732584. Delta is -0.0749704953109358
# WARNING:hmmlearn.base:Model is not converging.  Current: 3522.472746504217 is not greater than 3522.647842390375. Delta is -0.17509588615803295
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.264106956554 is not greater than 4233.416592857018. Delta is -0.15248590046394384
# WARNING:hmmlearn.base:Model is not converging.  Current: 3522.9247568654678 is not greater than 3522.960720857783. Delta is -0.035963992315373616
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.045950386874 is not greater than 4233.05835585058. Delta is -0.012405463705363218
# WARNING:hmmlearn.base:Model is not converging.  Current: 4206.5937887195705 is not greater than 4206.622486471144. Delta is -0.028697751573417918
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.030878428592 is not greater than 3523.082679276435. Delta is -0.05180084784296923
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.147876871891 is not greater than 4229.9219141607555. Delta is -1.774037288864747
# WARNING:hmmlearn.base:Model is not converging.  Current: 4025.539565111019 is not greater than 4025.768611418323. Delta is -0.22904630730408826
# WARNING:hmmlearn.base:Model is not converging.  Current: 3522.924756865476 is not greater than 3522.96072085778. Delta is -0.03596399230400493
# WARNING:hmmlearn.base:Model is not converging.  Current: 4233.0459503869615 is not greater than 4233.05835585056. Delta is -0.012405463598042843
# WARNING:hmmlearn.base:Model is not converging.  Current: 4206.593788719545 is not greater than 4206.622486471158. Delta is -0.02869775161252619
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.030878428595 is not greater than 3523.082679276423. Delta is -0.05180084782796257
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.147876871842 is not greater than 4229.921914160876. Delta is -1.7740372890348226
# WARNING:hmmlearn.base:Model is not converging.  Current: 4025.53956511095 is not greater than 4025.768611418253. Delta is -0.22904630730272402
# WARNING:hmmlearn.base:Model is not converging.  Current: 4226.992928072994 is not greater than 4227.241200406971. Delta is -0.24827233397718373
# WARNING:hmmlearn.base:Model is not converging.  Current: 4204.299062164134 is not greater than 4204.317916429713. Delta is -0.018854265578738705
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.8320995238955 is not greater than 4229.007627383729. Delta is -0.17552785983389185
# WARNING:hmmlearn.base:Model is not converging.  Current: 4203.412502433784 is not greater than 4203.435884932234. Delta is -0.02338249845070095
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.4490714492995 is not greater than 4234.4729181039875. Delta is -0.0238466546879863
# WARNING:hmmlearn.base:Model is not converging.  Current: 4232.356016879226 is not greater than 4232.442937738687. Delta is -0.08692085946040606
# WARNING:hmmlearn.base:Model is not converging.  Current: 3764.224396996657 is not greater than 3764.8283345242007. Delta is -0.6039375275436214
# WARNING:hmmlearn.base:Model is not converging.  Current: 4226.992928073002 is not greater than 4227.241200407009. Delta is -0.24827233400719706
# WARNING:hmmlearn.base:Model is not converging.  Current: 4204.299062164155 is not greater than 4204.317916429739. Delta is -0.018854265584195673
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.832099523933 is not greater than 4229.007627383518. Delta is -0.1755278595855998
# WARNING:hmmlearn.base:Model is not converging.  Current: 4203.4125024337745 is not greater than 4203.435884932219. Delta is -0.023382498444334487
# WARNING:hmmlearn.base:Model is not converging.  Current: 4234.449071449268 is not greater than 4234.472918103993. Delta is -0.023846654725275584
# WARNING:hmmlearn.base:Model is not converging.  Current: 4232.356016879209 is not greater than 4232.442937738639. Delta is -0.08692085942948324
# WARNING:hmmlearn.base:Model is not converging.  Current: 3764.2243969965352 is not greater than 3764.8283345242007. Delta is -0.6039375276654937
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.014523268497 is not greater than 4228.046155461533. Delta is -0.03163219303587539
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.807675551696 is not greater than 4201.928995738532. Delta is -0.12132018683587376
# WARNING:hmmlearn.base:Model is not converging.  Current: 4744.542610738822 is not greater than 4744.568469884288. Delta is -0.025859145465801703
# WARNING:hmmlearn.base:Model is not converging.  Current: 4202.174309270463 is not greater than 4202.1972367184235. Delta is -0.022927447960682912
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.252120620586 is not greater than 4201.535499356909. Delta is -0.28337873632335686
# WARNING:hmmlearn.base:Model is not converging.  Current: 4228.014523268487 is not greater than 4228.046155461576. Delta is -0.03163219308862608
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.8076755515885 is not greater than 4201.928995738467. Delta is -0.12132018687862
# WARNING:hmmlearn.base:Model is not converging.  Current: 4744.542610738796 is not greater than 4744.568469884331. Delta is -0.0258591455349233
# WARNING:hmmlearn.base:Model is not converging.  Current: 4202.174309270605 is not greater than 4202.197236718383. Delta is -0.022927447777874477
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.252120620557 is not greater than 4201.535499356902. Delta is -0.28337873634427524
# WARNING:hmmlearn.base:Model is not converging.  Current: 4206.103279669444 is not greater than 4206.106960576067. Delta is -0.003680906622321345
# WARNING:hmmlearn.base:Model is not converging.  Current: 4232.682389623833 is not greater than 4232.756938957822. Delta is -0.07454933398912544
# WARNING:hmmlearn.base:Model is not converging.  Current: 4231.723273627263 is not greater than 4232.108416772233. Delta is -0.38514314497024316
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.7884999548514 is not greater than 3523.8293764625655. Delta is -0.04087650771407425
# WARNING:hmmlearn.base:Model is not converging.  Current: 4220.067397813639 is not greater than 4220.517602284458. Delta is -0.45020447081878956
# WARNING:hmmlearn.base:Model is not converging.  Current: 4206.103279669419 is not greater than 4206.106960576078. Delta is -0.003680906658701133
# WARNING:hmmlearn.base:Model is not converging.  Current: 4232.682389623817 is not greater than 4232.756938957875. Delta is -0.07454933405824704
# WARNING:hmmlearn.base:Model is not converging.  Current: 4231.723273627238 is not greater than 4232.1084167722565. Delta is -0.3851431450184464
# WARNING:hmmlearn.base:Model is not converging.  Current: 3523.7884999548137 is not greater than 3523.8293764626173. Delta is -0.04087650780365948
# WARNING:hmmlearn.base:Model is not converging.  Current: 4220.067397813604 is not greater than 4220.517602284461. Delta is -0.45020447085698834
# WARNING:hmmlearn.base:Model is not converging.  Current: 4225.386965489194 is not greater than 4225.767518046429. Delta is -0.3805525572352053
# WARNING:hmmlearn.base:Model is not converging.  Current: 4678.97999368061 is not greater than 4679.443595612932. Delta is -0.46360193232158053
# WARNING:hmmlearn.base:Model is not converging.  Current: 4196.92879123254 is not greater than 4197.264200762917. Delta is -0.3354095303775466
# WARNING:hmmlearn.base:Model is not converging.  Current: 4227.730364021547 is not greater than 4228.040458376727. Delta is -0.31009435517989914
# WARNING:hmmlearn.base:Model is not converging.  Current: 4226.2986140142275 is not greater than 4226.926926894366. Delta is -0.6283128801387647
# WARNING:hmmlearn.base:Model is not converging.  Current: 4225.386965489149 is not greater than 4225.767518046441. Delta is -0.3805525572925035
# WARNING:hmmlearn.base:Model is not converging.  Current: 4678.97999368061 is not greater than 4679.443595612908. Delta is -0.46360193229793367
# WARNING:hmmlearn.base:Model is not converging.  Current: 4196.9287912325635 is not greater than 4197.264200762948. Delta is -0.3354095303848226
# WARNING:hmmlearn.base:Model is not converging.  Current: 4227.730364021404 is not greater than 4228.040458376727. Delta is -0.3100943553226898
# WARNING:hmmlearn.base:Model is not converging.  Current: 4226.298614014192 is not greater than 4226.926926894313. Delta is -0.6283128801205748
# WARNING:hmmlearn.base:Model is not converging.  Current: 4225.999331590199 is not greater than 4226.242493931584. Delta is -0.2431623413849593
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.696013868174 is not greater than 4201.750108200804. Delta is -0.05409433262957464
# WARNING:hmmlearn.base:Model is not converging.  Current: 4715.585702309368 is not greater than 4716.260094483925. Delta is -0.6743921745573971
# WARNING:hmmlearn.base:Model is not converging.  Current: 4225.999331590101 is not greater than 4226.242493931592. Delta is -0.24316234149137017
# WARNING:hmmlearn.base:Model is not converging.  Current: 4201.696013868173 is not greater than 4201.7501082008175. Delta is -0.05409433264412655
# WARNING:hmmlearn.base:Model is not converging.  Current: 4715.585702309293 is not greater than 4716.260094483959. Delta is -0.674392174665627

# %%
best_params ={'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}
# {'n_components': 9, 'covariance_type': 'diag', 'random_state': 57}

# %%
# Train the HMM model with the best parameters
model = GaussianHMM(**best_params, n_iter=100)
model.fit(train_data)
# Out:
# WARNING:hmmlearn.base:Model is not converging.  Current: 4711.181809980613 is not greater than 4711.206857510938. Delta is -0.025047530324627587
# GaussianHMM(n_components=9, n_iter=100, random_state=57)

# %%
all_pred, _ = model.sample(test_size+val_size+30)
all_pred = scaler.inverse_transform(all_pred.reshape(-1,1))
test_pred = all_pred[:test_size]
val_pred = all_pred[test_size:test_size+val_size]
thirty_day_pred = all_pred[test_size+val_size:]

# %%
y_test = scaler.inverse_transform(test_data)
y_val = scaler.inverse_transform(val_data)
evaluateModel(y_test,test_pred,y_val,val_pred)
# Out:
# ** Testing **
# MAE:  8515.060172333846
# MAPE:  26.853790368727825
# R-squared:  -0.589450099667961
# RMSE:  12427.107422628922
#
# ** Validate **
# MAE:  4852.865547792591
# MAPE:  21.39045594642298
# R-squared:  -3.6493742612718707
# RMSE:  5888.798313461559

# %%
train = df[:train_size]
test = df[train_size:train_size+test_size]
validate = df[train_size+test_size:]

# Plot the model
plt.plot(train.index, train.close, label='Train')
plt.plot(test.index, test.close, label='Test')
plt.plot(test.index, test_pred, label='Test Pridect')
plt.plot(validate.index, validate.close, label='Val')
plt.plot(validate.index, val_pred, label='Val Pridect')
plt.plot(df.index[-30:]+30, thirty_day_pred, label='Predict the next 30 days')
plt.legend()
plt.xlabel('Date')
plt.ylabel('close')
plt.show()
